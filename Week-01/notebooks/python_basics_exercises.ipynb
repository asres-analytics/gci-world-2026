# %% [markdown]
# # Week 01 — Python Basics Exercises 🐍
#
# Program: **GCI World 2026 (Global Consumer Intelligence)**
# Lab: **Matsuo‑Iwasawa Laboratory, University of Tokyo**
#
# This notebook contains practice exercises for Python fundamentals
# introduced in Week 01.

# %% [markdown]
# ## Objectives
#
# - Practice core Python syntax
# - Strengthen logical thinking using conditions and loops
# - Build confidence writing simple Python programs
# - Prepare for data manipulation in upcoming weeks

# %%
# Exercise 1: Variables and Data Types

age = 21
height = 1.70
name = "GCI Student"
is_enrolled = True

print(age, type(age))
print(height, type(height))
print(name, type(name))
print(is_enrolled, type(is_enrolled))
